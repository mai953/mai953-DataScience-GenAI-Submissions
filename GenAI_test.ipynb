# %% [markdown]
# Firstly, I want to import the data by uploading the file to Google Collab to work on the task.
#
# Source: I use the code from Github https://github.com/MJMortensonWarwick/IB2AD0_Data_Science_GenerativeAI/blob/main/2_05_Exploratory_Data_Analysis.ipynb
#
# Expectation: I expect the code will generate me a file upload button to upload the data.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from google.colab import files
upload = files.upload()
# Out:
#      <input type="file" id="files-6e42e29d-9cdc-4800-b30c-c77a0b102687" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6e42e29d-9cdc-4800-b30c-c77a0b102687">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# Checking: I see that I can upload the file successfully and 100%, therefore I know the code works.

# %% [markdown]
# Next step: I want to understand the specific content and structure of the data I've loaded. Therefore, I want to see the visualisation of the dataframe, looking at the column names and the first few rows of data.
#
# Source of code: Github with alternation by myself https://github.com/MJMortensonWarwick/IB2AD0_Data_Science_GenerativeAI/blob/main/2_05_Exploratory_Data_Analysis.ipynb
#
# Expectation: I expect to see all columns and the first five rows of the DataFrame.

# %%
df = pd.read_csv('in_class_test(in).csv')
df.head()
# Out:
#        Country  Year      Gender  Life Expectancy  Infant Mortality Rate  \
# 0  Afghanistan  1990  Both sexes           50.331                  120.4
# 1  Afghanistan  1990      Female           51.442                  114.2
# 2  Afghanistan  1990        Male           49.281                  126.2
# 3  Afghanistan  1991  Both sexes           50.999                  116.8
# 4  Afghanistan  1991      Female           52.119                  110.7
#
#    Low CI Value Infant Mortality Rate  High CI Value Infant Mortality Rate  \
# 0                               111.2                                130.9
# 1                               105.1                                124.7
# 2                               116.4                                137.5
# 3                               108.2                                126.2
# 4                               102.1                                120.4
#
#    Under 5 Mortality Rate  Low CI Value Under 5 Mortality Rate  \
# ...

# %% [markdown]
# Checking: I can see the columns and the first five rows of the DataFrame so the command works successfully.
#
# Interpretation and next step: The output of my DataFrame includes ellipsis as Pandas library has a default setting to limit the number of columns shown on the screen. I want to the the whole 150 columns to fully understand the data I am working with. Therefore, I will ask Gemini to generate me a code.
#
# Expectation: The code should show me all 150 columns and 5 rows in the dataframe.
#
# Prompt I fed into Gemini: "Use the DataFrame named df from in_class_test(in).csv, generate two consecutive Python commands required to display all columns and display the first 5 rows of the DataFrame 'df'".

# %%
pd.set_option('display.max_columns', None)
df.head()
# Out:
#        Country  Year      Gender  Life Expectancy  Infant Mortality Rate  \
# 0  Afghanistan  1990  Both sexes           50.331                  120.4
# 1  Afghanistan  1990      Female           51.442                  114.2
# 2  Afghanistan  1990        Male           49.281                  126.2
# 3  Afghanistan  1991  Both sexes           50.999                  116.8
# 4  Afghanistan  1991      Female           52.119                  110.7
#
#    Low CI Value Infant Mortality Rate  High CI Value Infant Mortality Rate  \
# 0                               111.2                                130.9
# 1                               105.1                                124.7
# 2                               116.4                                137.5
# 3                               108.2                                126.2
# 4                               102.1                                120.4
#
#    Under 5 Mortality Rate  Low CI Value Under 5 Mortality Rate  \
# ...

# %% [markdown]
# Checking: I can see all columns and the first five rows of the DataFrame so the command works successfully.
#
# Interpretation: There are multiple explicit missing values visible in the first five rows as seen in many "NaN".
#
# Next step, since quality of data is an extremely important aspect of data science and machine learning, I want check how many null values the data have for each column.
#
# I use Gemini to generate my code.
#
# My prompt is "Using the DataFrame 'df' from the file 'in_class_test(in).csv',generate a Python code block required to  count the total number of missing values for every column. This code must use the .isnull().sum() method on the df DataFrame 'df'."
#
# I expect to see the number of missing data of each columns.

# %%
df.isnull().sum()
# Out:
# Country                            0
# Year                               0
# Gender                             0
# Life Expectancy                    0
# Infant Mortality Rate           7593
#                                 ...
# Cereal Consumption Rice         9084
# Diet Calories Animal Protein    9972
# Diet Calories Plant Protein     9972
# Diet Calories Fat               9972
# Diet Calories Carbohydrates     9972
# Length: 150, dtype: int64

# %% [markdown]
# Checking: I can see the number of missing data from each columns of the DataFrame (now represented as rows) and there are 150 rows corresponding to 150 columns so I know my code works.
#
# Interpretation: There are many missing values in this data for example, there are 7593 missing data for infant mortality rate while 0 missing data on gender.
#
# Next-step: I can work with an SME to see the importance of these missing values. For now, I will delete the columns that contain these missing values because I want to maintain data consistency i.e. every rows must not have missing data.

# %% [markdown]
# I now will ask Gemini to delete the columns with missing values. I expect to see a DataFrame with rows and columns without missing values.

# %% [markdown]
# Note: Due to time constraint, I will not include the prompt I use for Gemini if I use Gemini to generate code. But I will still follow the same practice of being specific when prompting so I can control Gemini and not let it control me.

# %%
df = df.dropna(axis=1)
df.head()
# Out:
#        Country  Year      Gender  Life Expectancy
# 0  Afghanistan  1990  Both sexes           50.331
# 1  Afghanistan  1990      Female           51.442
# 2  Afghanistan  1990        Male           49.281
# 3  Afghanistan  1991  Both sexes           50.999
# 4  Afghanistan  1991      Female           52.119

# %% [markdown]
# I can confirm my code works as I see no missing values in my dataframe.

# %% [markdown]
# Now I will visualise my data, I want to predict life expectancy based on Gender. Therefore, I will ask Gemini to plot me a box plot graph.
#
# I expect to see a boxplot graph.

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='Gender', y='Life Expectancy', data=df)
plt.title('Life Expectancy by Gender')
plt.xlabel('Gender')
plt.ylabel('Life Expectancy')
plt.grid(axis='y', linestyle='--')
plt.show()

# %% [markdown]
# I see that the code works as I see the graph:
#
# I run out of time to interpret this graph throughly but female seems to have higher life expectancy than male.

# %% [markdown]
# After this, I will visualise other data such as year borned vs life expenctancy.
